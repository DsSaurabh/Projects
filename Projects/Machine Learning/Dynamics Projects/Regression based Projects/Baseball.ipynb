# %%
#Importing all the necessary library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Importing the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [raw]
# Remark: Baseball statistics play an important role in evaluating the progress of a player or team. Describe all the
#          feature according to different diffirent feature.
#
# 1. Batting statistics:
#
# R – Runs scored: number of times a player crosses home plate.
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or
#      obstruction.
# H – Hit: reaching base because of a batted, fair ball without error by the defense.
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error.
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and
#       awarded first base.
# PA/SO – Plate appearances per strikeout: number of times a batter strikes out to their plate appearance.
#
# 2. Baserunning statistics:
#
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.
# R – Runs scored: times reached home plate legally and safely.
#
# 3. Pitching statistics:
#
# BB – Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base.
# CG – Complete game: number of games where player was the only pitcher for his team.
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls.
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense
#     benefits as a result.
# SHO – Shutout: number of complete games pitched with no runs allowed.
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without
#     surrendering the lead.
# RA – Run average: number of runs allowed times nine divided by innings pitched.
#
# HR (or HRA) – Home runs allowed: total home runs allowed.
#
# W – Win: number of games where pitcher was pitching while his team took the lead and went on to win, also the
# starter needs to pitch at least 5 innings of work (also related: winning percentage)

# %%
#Columns full names
#columns=['Wins','Runs','At Bats','Hits','Doubles','Triples','Homeruns','Walks','Strikeouts','Stolen Bases',
#         'Runs Allowed','Earned Runs','Earned Run Average','Shutouts','Saves','Error']

# %%
#Checking the columns
df.shape
# Out:
# (30, 17)

# %% [markdown]
# In this dataset there are 30 rows and 17 columns are present

# %%
#Checking the various columns
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#Checking the data types of the columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Observation:
#
#     1-30 rows and 17 columns are present in our dataset.
#
#     2-There are no missing value present in our dataset.
#
#     3-All the columns are in int64 data type except ERA.
#
#     4-ERA column data is in float64.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# Observation:
#
#     1-Standard deviation is maximun in SO(Strikeouts).
#
#     2-Minimum number wins is 63 and Maximun number of wins is 100.
#
#     3-In HR,SB,ER,SHO,SV,E columns the difference between 75% and max is more so in these columns outliers may be
#        present.
#
#     4-The minimum run scored is 573.

# %%
#Checking the unique wins
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
#Checking the value counts for wins.
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# Observation:
#
#     1-According to our dataset most frequent wins is 68.It happens three times.
#
#     2-Also a team wins games for two times is for 83,81,76,74.

# %% [markdown]
# ## Checking for Missing values

# %%
#Checking for null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Observation:
#
#     There is no null Value in our dataset. We can also see this with the help of Visualization for better clearity.

# %%
#Seeing the null value with the help of heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='tab10',annot=True)

# %% [markdown]
# Observation:
#
#     From this visualization we can clearly see that there is no missing values present in our dataset.

# %% [markdown]
# # To check the correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %% [markdown]
# Here we can see the correlation between the columns.
#
# For better understanding we can see it via visualization (with the help of heatmap).

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_cor,annot=True,cmap='winter')

# %% [markdown]
# Observation:
#
#     1-RA,ERA,ER is highly negatively correlated with wins.
#
#     2-SV,SHO is negatively correlated with RA,ERA,ER.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(10,7))
df['W'].plot.bar()
plt.ylabel('No of Wins')
plt.xlabel('No of Rows')
plt.xticks(rotation=30)
plt.title("No of Wins per Row")
plt.show()

# %% [markdown]
# Observation:
#
#     1-Row 15 wins 100 times.
#
#     2-Row 24 wins 63 times.

# %%
plt.figure(figsize=(10,7))
df['HR'].plot.bar()
plt.ylabel('Home Runs for each row')
plt.xlabel('No of Rows')
plt.xticks(rotation=30)
plt.title("No of Home Runs per row")
plt.show()

# %% [markdown]
# Observation:
#
#     1-Row 5 makes 232 home run.
#
#     2-Row 23 makes 99 home run.

# %%
plt.figure(figsize=(10,7))
df['R'].plot.bar()
plt.ylabel('No of Runs')
plt.xlabel('No of Rows')
plt.xticks(rotation=30)
plt.title("No of Runs per row")
plt.show()

# %% [markdown]
# Observation:
#
#     1-Row 5 makes more than 900 runs.
#
#     2-Row 23 makes 600 runs approx.

# %%
df['ERA'].plot.hist(bins=20)
plt.title("Histogram of Earned runs averaged(ERA)")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(df['W'])
plt.show()

# %% [markdown]
# Observation:
#     Maximum wins is between 70 to 90.

# %%
sns.violinplot(df['AB'])
plt.show()

# %% [markdown]
# Observation:
#     Mostly AB is between 5450 to 5500.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['W'])
plt.show()

# %% [markdown]
# Observation:
#
#     1-No of Wins for 68 times is three times.
#
#     2-No of Wins for 74,76,81,83,is two times.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['SHO'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['E'])
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.set(style='white')
plt.scatter(df['R'],df['W'])
plt.xlabel('No of Runs')
plt.ylabel('No of Wins')
plt.title("Scatter plot of No of Runs vs No of Wins")
plt.show()

# %% [markdown]
# Observation:
#
#     When Runs is between 710 to 790  number ofwinning  is more than 85.

# %%
plt.scatter(df['ERA'],df['W'])
plt.show()

# %% [markdown]
# Observation:
#
#     1-When Value of ERA is less than 3.5 than winning chance is more than 90.
#
#     2-When value of ERA is more than 4.2 than winning chance is less than 70.

# %%
sns.regplot(x='SV',y='W',data=df,fit_reg=False)
plt.title('Scatter plot of Saves and Wins')
plt.show()

# %% [markdown]
# Observation:
#
#     1- Winning is more when SV value is more than 42 and minimum when SV value below than 45.

# %%
sns.regplot(x='SO',y='W',data=df,fit_reg=False)
plt.title('Scatter plot of Strikeout and Wins')
plt.show()

# %% [markdown]
# Observation:
#
#     Winning is more than 75 times when strikeout value is between 1150 to 1350.

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='AB',y='W',data=df)
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='H',y='3B',data=df)
plt.xticks(rotation=20)
plt.show()

# %%
#sns.pairplot(df,hue='W')

# %% [markdown]
# # Plotting Outliers

# %%
df['E'].plot.box()

# %%
df['SHO'].plot.box()

# %%
df.shape
# Out:
# (30, 17)

# %%
collist=df.columns.values
ncol=17
nrow=10

# %%
plt.figure(figsize=(16,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # To check the distribution of Skewness

# %%
plt.figure(figsize=(30,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]],color='green')
    plt.tight_layout()

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
#Checking skewness of data
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#Treating skewness via log method

for col in df.columns:
    if df[col].skew()>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO   -0.589640
# SV     0.163057
# E      0.632916
# dtype: float64

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.3654086 , 0.66532946, 0.84773126, 1.64938177, 1.42017307,
#         1.04119304, 0.7872986 , 1.53490242, 2.69762957, 0.91388329,
#         0.66623393, 0.50511008, 0.50695519, 0.27892148, 0.72910756,
#         1.58127344, 0.42706021],
#        [0.1978383 , 0.17956168, 0.71109353, 0.98165584, 0.12740339,
#         1.23580856, 0.24396668, 0.5365919 , 0.15487844, 0.60182558,
#         0.16597077, 0.24892985, 0.25459752, 0.27892148, 0.32263825,
#         0.336185  , 0.59169263],
#        [0.00324325, 0.30770406, 1.1152333 , 0.13421019, 1.58879521,
#         0.22380785, 0.7233772 , 1.13914361, 0.89398189, 0.11144918,
#         0.68033909, 0.75162313, 0.64134684, 1.76277761, 0.15516048,
#         0.62244106, 1.19928939],
#        [0.48324437, 1.20472969, 0.24152162, 0.38913576, 0.82812203,
#         0.41842337, 0.8831807 , 1.16053598, 0.16860185, 0.69098493,
#         0.18007593, 0.10392217, 0.05301004, 1.16561891, 0.42776132,
#         0.77328196, 0.56049482],
#        [0.67783942, 0.05507026, 1.28073815, 1.95148012, 0.80189192,
#         1.72234737, 0.40377019, 0.25136033, 0.10586628, 0.02228984,
#         1.61880269, 1.59750126, 1.53131824, 1.16561891, 0.32263825,
#         1.08725291, 0.59169263],
#        [1.17081355, 3.22198296, 0.10488389, 1.36071482, 1.86983209,
#         1.39150098, 2.18504658, 1.79874163, 0.95279649, 0.20060853,
#         0.25718416, 0.38910394, 0.35016492, 1.16561891, 0.15516048,
#         1.25084255, 0.42706021],
#        [0.5870284 , 1.3276866 , 0.73226276, 0.0980011 , 0.1536335 ,
#         1.19688546, 1.54583256, 1.51351006, 0.20781158, 0.91388329,
#         0.13776044, 0.23442908, 0.16500309, 0.14476936, 2.41026205,
#         0.70306792, 0.0311412 ],
#        [0.00324325, 0.47676732, 0.4512894 , 0.5912527 , 1.61502532,
#         1.0995777 , 1.70563607, 0.91095835, 0.81164146, 1.76089707,
#         0.06723462, 0.14742447, 0.20980031, 1.89692973, 0.15516048,
#         0.07805147, 1.38267931],
#        [0.09405427, 0.77671257, 0.4512894 , 0.35256013, 0.18361077,
#         0.06811543, 0.10760103, 0.59007283, 0.60579036, 0.15602885,
#         0.65212876, 0.46160778, 0.48455658, 0.87608018, 0.32263825,
#         1.97512252, 0.12135948],
#        [0.28864932, 1.06699657, 1.78591286, 1.61559145, 1.08292881,
#         0.16542319, 0.08416318, 0.15866006, 0.98220379, 0.55724591,
#         0.91354447, 0.84346133, 0.79216414, 0.14476936, 0.15516048,
#         0.33202814, 0.27071559],
#        [0.68432592, 1.11629752, 0.07601676, 0.29691464, 0.23981814,
#         0.06811543, 0.26740453, 0.6043344 , 0.14899698, 0.78014427,
#         0.63144119, 0.64045058, 0.63537388, 0.74192807, 0.42776132,
#         0.336185  , 1.73770307],
#        [0.48973087, 0.75009569, 0.82656204, 0.72071866, 0.18361077,
#         0.51573113, 2.12112518, 0.30127585, 1.40958987, 1.67173773,
#         0.99065271, 0.92563235, 0.86533293, 0.74192807, 0.53459772,
#         0.47541933, 0.67543362],
#        [0.39243335, 0.45585524, 1.43277168, 1.32115147, 1.78364745,
#         1.00226994, 0.39524733, 0.6078998 , 0.96259892, 1.40425969,
#         0.18665834, 0.08458781, 0.03658439, 0.27892148, 0.32263825,
#         0.46107257, 0.0311412 ],
#        [0.48324437, 0.54936166, 0.40029081, 0.42576436, 0.71570727,
#         0.90496218, 1.09838275, 0.15866006, 0.86065362, 0.64640525,
#         0.53270504, 0.59694828, 0.45618501, 0.96895727, 0.32263825,
#         0.336185  , 0.04551046],
#        [1.26162457, 0.14412074, 1.20857034, 0.04631909, 0.12740339,
#         1.43042408, 0.56357369, 0.10517914, 1.26647435, 0.2451882 ,
#         0.57502053, 0.40843829, 0.41138779, 0.74192807, 0.91651672,
#         2.34287091, 2.14837662],
#        [1.85189622, 0.71948073, 0.46572296, 0.29779567, 0.74568454,
#         0.74926976, 0.85122   , 0.65781532, 0.18428574, 0.64640525,
#         2.30243298, 2.28870452, 2.2764453 , 0.87608018, 0.91651672,
#         2.1624629 , 0.19642248],
#        [1.65730117, 0.19724403, 1.65601079, 1.05143325, 0.97051405,
#         0.41842337, 0.7553379 , 0.14439849, 0.72341956, 0.64640525,
#         1.30096632, 1.50566306, 1.67168286, 1.89692973, 0.53459772,
#         1.37385682, 1.91656437],
#        [1.56000365, 0.05507026, 0.36468802, 1.13198047, 0.1536335 ,
#         0.12650009, 0.23544383, 1.74526071, 2.64469643, 0.51266624,
#         1.13170435, 1.30265231, 1.33570372, 0.96895727, 1.82734024,
#         0.70306792, 1.23795219],
#        [1.26162457, 0.56814831, 0.52345722, 0.44409857, 0.04121874,
#         0.26273095, 0.59553439, 1.01792019, 0.4979636 , 0.02228984,
#         0.68786185, 0.66945211, 0.72496831, 0.87608018, 1.065984  ,
#         0.33202814, 1.55431315],
#        [1.65081467, 0.85343715, 0.78999701, 0.37084133, 0.99674416,
#         0.41842337, 0.10760103, 0.47954559, 0.06665654, 2.25127347,
#         0.92764964, 0.93046594, 0.83696136, 0.27892148, 0.72910756,
#         1.08725291, 0.2660866 ],
#        [0.87892097, 0.05264604, 0.15492024, 0.94421388, 1.13913619,
#         1.39150098, 0.42720803, 0.3369298 , 0.4097417 , 1.44883936,
#         1.06117853, 1.14314386, 1.17891346, 0.87608018, 0.73192726,
#         0.93538083, 0.42706021],
#        [0.1978383 , 0.30280904, 1.27400249, 0.72071866, 0.54708514,
#         1.78073202, 0.42720803, 1.24610545, 0.93907309, 1.18136133,
#         0.75086491, 0.85312851, 0.75333989, 0.47340951, 0.53459772,
#         0.1920925 , 0.2660866 ],
#        [0.969732  , 1.38420083, 0.76882779, 0.31471967, 2.17709909,
#         0.84657752, 1.39455191, 1.67751821, 0.96259892, 1.27052067,
#         0.14434285, 0.03141833, 0.14260448, 1.89692973, 0.32263825,
#         1.08725291, 1.38267931],
#        [1.3589221 , 2.21504941, 1.38947099, 0.75783098, 1.33398843,
#         1.29419322, 2.03376593, 0.03387125, 1.38410355, 0.64640525,
#         1.01228062, 0.9014644 , 1.01615023, 0.14476936, 0.15516048,
#         0.20855243, 0.2660866 ],
#        [1.74811219, 1.12579542, 0.18378737, 0.51756862, 0.1536335 ,
#         0.55465424, 1.07494491, 1.46359453, 0.25290277, 0.20060853,
#         1.70343367, 1.64100356, 1.64331129, 0.87608018, 1.065984  ,
#         1.08725291, 1.61596046],
#        [1.07351602, 0.34457535, 1.8946457 , 1.03792293, 0.6594999 ,
#         0.51573113, 0.74681504, 1.67395282, 0.09606384, 1.09220198,
#         1.31507148, 1.20114693, 1.15651485, 0.96895727, 1.82734024,
#         0.58333073, 1.57083312],
#        [0.29513583, 0.17956168, 0.70339563, 1.4629739 , 0.74568454,
#         0.74926976, 0.8831807 , 0.21570638, 0.87437703, 0.42350689,
#         0.86370623, 0.56311315, 0.52935379, 1.16561891, 1.4080332 ,
#         0.1920925 , 1.29040399],
#        [0.1913518 , 0.5970945 , 1.91581492, 1.59867936, 0.80189192,
#         1.6250396 , 0.30788808, 0.37258375, 0.62539523, 2.16211413,
#         0.3493379 , 0.33593445, 0.1874017 , 0.87608018, 0.32263825,
#         0.20855243, 0.59169263],
#        [0.67783942, 0.66251325, 0.85542916, 1.4544181 , 0.82812203,
#         0.45734648, 0.49965229, 0.76834256, 0.77243172, 0.06686951,
#         0.60323086, 0.27793138, 0.29939474, 0.87608018, 1.44790301,
#         0.1920925 , 0.10861268],
#        [1.26162457, 0.88452141, 0.80443057, 1.34363137, 0.04121874,
#         1.72234737, 0.71485434, 1.44576756, 0.34112467, 0.60182558,
#         2.19711442, 2.36604195, 2.42726261, 0.47340951, 2.41026205,
#         0.92814575, 0.12135948]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print(df.shape,'\t',df_new.shape)
# Out:
# (30, 17) 	 (29, 17)

# %%
df=df_new
print(df.shape)
# Out:
# (29, 17)

# %% [markdown]
# Now our EDA process is done.

# %% [markdown]
# # Model Training

# %%
#Seprating into input and output variables.

df_x=df.drop(columns=['W'])

# %%
y=pd.DataFrame(df['W'])

# %%
#Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets again Check the skewness
x.skew()
# Out:
# R     -0.388428
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO   -0.598073
# SV     0.109983
# E      0.586101
# dtype: float64

# %%
#Breaking our input and target variable into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
print(x_train.shape,'\t',x_test.shape)
# Out:
# (23, 16) 	 (6, 16)

# %%
print(y_train.shape,'\t',y_test.shape)
# Out:
# (23, 1) 	 (6, 1)

# %%
#Importing our Models Library

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Importing Error Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#Using algorithms via for loop

model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean absolute error:',mean_absolute_error(y_test,predm))
    print('Mean squared error:',mean_squared_error(y_test,predm))
    print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predm)))
    print("r2_score:",r2_score(y_test,predm))
    print('************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False) is: 0.9690144555689814
# Error:
# Mean absolute error: 6.295848811682506
# Mean squared error: 59.477553716391206
# Root Mean Squared Error: 7.712169196561445
# r2_score: 0.3825859475807142
# ************************************************************************************************
#
#
# Score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') is: 1.0
# Error:
# Mean absolute error: 7.666666666666667
# Mean squared error: 100.33333333333333
# Root Mean Squared Error: 10.016652800877813
# r2_score: -0.04152249134948094
# ************************************************************************************************
#
#
# Score of KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') is: 0.7821121688594146
# Error:
# Mean absolute error: 6.033333333333334
# Mean squared error: 62.21999999999999
# Root Mean Squared Error: 7.887965517166007
# r2_score: 0.35411764705882365
# ************************************************************************************************
#
#
# Score of SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) is: 0.26108271325492827
# Error:
# Mean absolute error: 7.952779111693133
# Mean squared error: 85.93827481444197
# Root Mean Squared Error: 9.2702898991586
# r2_score: 0.10790718185700376
# ************************************************************************************************
#
#
# Score of Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False) is: 0.88870082887641
# Error:
# Mean absolute error: 3.754795556571343
# Mean squared error: 20.983780418029802
# Root Mean Squared Error: 4.580805651632669
# r2_score: 0.7821752897782374
# ************************************************************************************************
#
#
# Score of Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001) is: 0.9399670638035899
# Error:
# Mean absolute error: 3.939012689116358
# Mean squared error: 27.93118647074559
# Root Mean Squared Error: 5.284996354846954
# r2_score: 0.7100568878469316
# ************************************************************************************************
#
#
# Score of ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False) is: 0.8791163407098292
# Error:
# Mean absolute error: 4.485546028206843
# Mean squared error: 32.512434573451216
# Root Mean Squared Error: 5.701967605436847
# r2_score: 0.6625006791683266
# ************************************************************************************************

# %%
#Cross Validate the models
from sklearn.model_selection import cross_val_score
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    score=cross_val_score(m,x,y,cv=4,scoring='r2')
    print('Score of',m,'is:')
    print("Score:",score)
    print('Mean Score:',score.mean())
    print("Standard deviation:",score.std())
    print('************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False) is:
# Score: [-0.25799608 -2.53778626  0.74140884  0.02469007]
# Mean Score: -0.5074208554514873
# Standard deviation: 1.227529432233261
# ************************************************************************************************
#
#
# Score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') is:
# Score: [-1.73203157  0.57827476 -0.33253012  0.14365009]
# Mean Score: -0.33565921146568817
# Standard deviation: 0.8681702422183771
# ************************************************************************************************
#
#
# Score of KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') is:
# Score: [0.41477358 0.5284984  0.60273735 0.63657194]
# Mean Score: 0.545645316269307
# Standard deviation: 0.08507141001016104
# ************************************************************************************************
#
#
# Score of SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) is:
# Score: [-0.10576043  0.0038076   0.10287002 -0.18727202]
# Mean Score: -0.04658870872301618
# Standard deviation: 0.10973922122112219
# ************************************************************************************************
#
#
# Score of Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False) is:
# Score: [0.50559501 0.79307556 0.79560255 0.90926435]
# Mean Score: 0.7508843686442415
# Standard deviation: 0.14919023129278744
# ************************************************************************************************
#
#
# Score of Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001) is:
# Score: [0.23535133 0.441917   0.86123372 0.8559577 ]
# Mean Score: 0.5986149382504036
# Standard deviation: 0.2700502792248584
# ************************************************************************************************
#
#
# Score of ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False) is:
# Score: [0.49429497 0.74459798 0.76291241 0.88894157]
# Mean Score: 0.7226867334670619
# Standard deviation: 0.14309234386597075
# ************************************************************************************************

# %% [markdown]
# ### Ridge model is giving best score.

# %%
#Ridge model is giving best result so finding its best parameter using GridSearchCV
from sklearn.model_selection import GridSearchCV
ridge=Ridge()
parameters={'alpha':[0.001,0.01,0.1,1],'random_state':range(42,100)}
clf=GridSearchCV(ridge,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1, 'random_state': 42}

# %%
#Using Ridge model with best results

ridge=Ridge(alpha=1,random_state=42)
ridge.fit(x_train,y_train)
print('Score:',ridge.score(x_train,y_train))
predrd=ridge.predict(x_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y_test,predrd))
print('Mean squared error:',mean_squared_error(y_test,predrd))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
print('\n')
print("r2_score:",r2_score(y_test,predrd))
# Out:
# Score: 0.9399670638035899
#
#
# Mean absolute error: 3.939012689116358
# Mean squared error: 27.93118647074559
# Root Mean Squared Error: 5.284996354846954
#
#
# r2_score: 0.7100568878469316

# %%
#Cross Validate Ridge

score=cross_val_score(ridge,x,y,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [0.23535133 0.441917   0.86123372 0.8559577 ]
# Mean Score: 0.5986149382504036
# Standard deviation: 0.2700502792248584

# %% [markdown]
# ## Using Ensemble Technique to Boostup our score

# %%
#Using Random Forest

from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=20,random_state=59)
rf.fit(x_train,y_train)
print('Score:',rf.score(x_train,y_train))
predrf=rf.predict(x_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y_test,predrf))
print('Mean squared error:',mean_squared_error(y_test,predrf))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
print('\n')
print("r2_score:",r2_score(y_test,predrf))
# Out:
# Score: 0.9286277944165151
#
#
# Mean absolute error: 5.6166666666666645
# Mean squared error: 44.50749999999999
# Root Mean Squared Error: 6.6713941571458655
#
#
# r2_score: 0.5379844290657441

# %%
#Using Ada Boost

from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()

adb=AdaBoostRegressor(base_estimator=lasso,n_estimators=20,learning_rate=0.1,random_state=59)
adb.fit(x_train,y_train)
print('Score:',adb.score(x_train,y_train))
predadb=adb.predict(x_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y_test,predadb))
print('Mean squared error:',mean_squared_error(y_test,predadb))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predadb)))
print('\n')
print("r2_score:",r2_score(y_test,predadb))
# Out:
# Score: 0.8812238510479312
#
#
# Mean absolute error: 3.073860038179968
# Mean squared error: 19.249454698860465
# Root Mean Squared Error: 4.387420050423764
#
#
# r2_score: 0.8001786709460852

# %% [markdown]
# AdaBoostRegressor is working well because it gives the best r2_score and also it is not suffering from overfitting and
# Underfitting.
#
# So we save AdaBoost Regressor as our final Model.

# %%
#Cross Valiodate AdaBoostRegressor

score=cross_val_score(adb,x,y,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [0.55018611 0.77659435 0.8076274  0.72441817]
# Mean Score: 0.7147065074340784
# Standard deviation: 0.09953099368132796

# %%
#Plotting scatter plot between test data and predicted data for Ada Boost
plt.scatter(y_test,predadb)
plt.xlabel('y_test')
plt.ylabel('Predicted Y')
plt.title("Scatter plot between test data and predicted data")
plt.show()

# %%
#Saving the AdaboostRegressor
from sklearn.externals import joblib
joblib.dump(adb,'Baseball.pkl')
# Out:
# ['Baseball.pkl']
